# %%
5 in [1, 2, 3]
# Out:
# False

# %%
3 >= 8
# Out:
# False

# %%
a = [1, 2, 3] # 여기서 = 는 오른쪽 항을 왼쪽으로 대입한다는 뜻

1 == 2
1 != 2
# Out:
# True

# %%
scores = [85, 92, 78, 90, 88, 76, 95, 89]
print(len(scores))
# Out:
# 8

# %%
print(max(scores))
# Out:
# 95

# %%
print(min(scores))
# Out:
# 76

# %%
print(sum(scores))
# Out:
# 693

# %%
print(list("Hello world"))
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd']

# %%
print("a,b,c,d,e".split(","))
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
print(" ".join(["python", "is", "fun"]))
# Out:
# python is fun

# %%
print(list(map(int,"12345")))
# Out:
# [1, 2, 3, 4, 5]

# %%
a = []

a.append(10)

# %%
data = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
print(data.index(5,5))
# Out:
# 8
