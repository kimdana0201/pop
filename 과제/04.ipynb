# %%
a = 5
b = -3
c = 10

a + b 
a * b
a / b
b ** c
# Out:
# 59049

# %%
5 % 2
# Out:
# 1

# %%
6 % 5
# Out:
# 1

# %%
2 % 9
# Out:
# 2

# %%
9 / 4
# Out:
# 2.25

# %%
a = 1

# %%
a = a + 1
print(a)
# Out:
# 2

# %%
a += 1
a
# Out:
# 4

# %%
a = 1
a -= 1 
print(a)
# Out:
# 0

# %%
a = 2
a *= 2
a
# Out:
# 4
