# %%
# list는 어떻게 만들까?
odd = [1, 3, 5, 7, 9]

a = []  #비어 있는 리스트 선언, 타입을 지정 안하는 것(자동으로 지정)이 파이썬 특징 그러나 복잡한 코드를 짤 때는 리스트를 지정해줘야됨.
b = [1, 2, 3]
c = ["life", "is", "short"] # 비어 있는 값, 숫자, 문자 등 다양하게 선언가능
d = [1, 2, ["life", "is"]]

# %%
# 리스트의 인덱싱(중요)
a = [1, 2, 3]
a[0]
a[0] + a[2]
# Out:
# 4

# %%
a = [1, 2, 3, ["a", "b", "c"]]
a[3][-1]
a[-1][-1]
# Out:
# 'c'

# %%
a = [1, 2, ["a", "b", ["life", "is"]]]
len(a)
a[-1][-1][-2]  

#이 부분 더 공부
# Out:
# 'life'

# %%
# 리스트의 슬라이싱
a = [1, 2, 3, 4, 5]
a[0:1+1]
a[0:3+1]
# Out:
# [1, 2, 3, 4]

# %%
a = [1, 2, 3, ["a", "b", "c"], 4, 5]
a[3][0:1+1]
# Out:
# ['a', 'b']

# %%
# 리스트 더하기 (각자 더하기가 아닌 결합)
a = [1, 2, 3]
b = [4, 5, 6]

a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 리스트 곱하기
a = [1, 2, 3]
a * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# 리스트 길이 구하기
a = [1, 2, 3, 4, 5]
len(a)
# Out:
# 5

# %%
# 리스트의 수정과 삭제
a = [1, 2, 3]
a[2] = 4 #2번 자리에 4를 대입하겠다는 뜻
a
# Out:
# [1, 2, 4]

# %%
# del로 리스트 요소 삭제
a = [1, 2, 3]
del a[1]
print(a)
# Out:
# [1, 3]

# %%
a = [1, 2, 3, 4, 5]
del a[2:]
print(a)
# Out:
# [1, 2]

# %%
# 리스트 관련 함수
## 리스트 요소 추가하기 - append() , 아마 가장 많이 쓰임

a = [1, 2, 3]
# b =[4]
# a + b

a.append(4)
a
# Out:
# [1, 2, 3, 4]

# %%
# 리스트 정렬 - sort (오름차순)
a = [1, 4, 3, 2]
a.sort()
a
# Out:
# [1, 2, 3, 4]

# %%
a = ["a", "c", "b", "d"]
a.sort()
a
# Out:
# ['a', 'b', 'c', 'd']

# %%
a = [1, 2, 3]

str(a[2]) + "hi"
# Out:
# '3hi'

# %%
# 리스트 정렬 - reverse
a = [1, 4, 3, 2]
a.sort()
a.sort(reverse=True)
a
# Out:
# [4, 3, 2, 1]

# %%
a = ["b", "a", "c"]
a.reverse()
a
# Out:
# ['c', 'a', 'b']

# %%
# 인덱스 반환 - index
a = [1, 2, 3]
a.index(1)
a.index(2)
a.index(3)
# Out:
# 2

# %%
# 리스트에 요소 삽입
a = [1, 2, 3]
a.insert(0, 4)
a.insert(3, 5)
a
# Out:
# [4, 1, 2, 5, 3]

# %%
a.insert(3, 5)
a
# Out:
# [4, 1, 2, 5, 5, 3]

# %%
# 리스트요소 제거 - remove
a = [1, 2, 3, 1, 2, 3]
a.remove(3)
a
# Out:
# [1, 2, 1, 2, 3]

# %%
a.remove(3)
a
# Out:
# [1, 2, 1, 2]

# %%
# 리스트 요소 꺼내기 - pop
a = [1, 2, 3]
a.pop() # 기본값이 -1 = 3이라 다시 출력시 3이 나감
a
# Out:
# [1, 2]

# %%
a = [1, 2, 3]
a.pop()
a
# Out:
# [1, 2]

# %%
# 리스트에 포함된 요소 x의 개수 세기 - count
a = [1, 2, 3, 1]
a.count(2)
# Out:
# 1

# %%
# 리스트 확장 - extend
a = [1, 2, 3]
a.extend([5, 4])
a
# Out:
# [1, 2, 3, 5, 4]
