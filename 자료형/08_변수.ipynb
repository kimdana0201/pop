# %%
# 변수는 어떻게 만들까?

a = 1
b = "python"
c = [1, 2, 3]

# %%
# 변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_)만 사용할 수 있다.

a1 = 1
t1 = 2
type_script = 1 #type_script_1234 = 1 도 가능
# type-script = 1 / 이건 사용 불가 (-) 빼기로 인식
typeScript = 1
TypeScript = 1

# 2. 숫자로 시작할 수 없다.
# 3. 예약어는 사용할 수 없다. 
# print, len, False, and, break, if, from 파이썬에서 기능을 가지고 있는 것들 사용 금지
# ex) print = 1로 지정하면 print의 기능을 사용 할 수 없다. (만약 예약어 기능을 상실 시켰다면 builtins 함수 사용)
# 4. 대소문자를 구분한다.
abc = 1 
ABC = 2

print(ABC)
print(abc)
# Out:
# 2
# 1

# %%
a, b = "python", "Life" #a, b에 각각 부여, (a, b) 소괄호가 생략된 상태라 그럼
print(a)
print(b)
# Out:
# python
# Life

# %%
[a, b] = ["python", "life"]
print(a)
print(b)
# Out:
# python
# life
