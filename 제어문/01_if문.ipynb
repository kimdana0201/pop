# %%
# IF문은 왜 필요할까?
"돈이 있으면 택시를 타고 가고, 돈이 없으면 걸어간다"
# Out:
# '돈이 있으면 택시를 타고 가고, 돈이 없으면 걸어간다'

# %%
money = True

if money: print("택시를 타고 가라.")
else: print("걸어가라.")
# Out:
# 택시를 타고 가라.

# %%
# if 문의 기본구조

# if 조건문:  #: = 그러면(문장이 이어나간다 라는 뜻)
#     수행할 문장1
#     수행할 문장2
#     ...
# #내어쓰기 shift + tap 
# else: 
#     수행할 문장1
#     수행할 문장2
#     ...

# %%
# 들여쓰기 방법

# if 조건문:
#     수행할 문장1
#수행할 문장2 -> if문 안에서 실행이 되지 않음
#     수행할 문장3 

money = True
if money:
    print("택시를")
    print("타고")
    print("가라")
# Out:
# 택시를
# 타고
# 가라

# %%
money = True
if money:
    print("택시를")
print("타고")
    # print("가라") . 위 택시를에서 if문이 끝났기 때문에 print("타고")는 실행이 된다.
# Out:
# 택시를
# 타고

# %%
# money = True
# if money:
#     print("택시를")
#     print("타고")
#         print("가라") -> 들여쓰기는 언제나 같은 깊이로 해야 한다(tap)

# %%
money = 2000
if money >= 3000:  #-> 이 식의 값은 True or Fales가 된다
    print("택시를 타고 가라")
else:
    print("걸어가라")
# Out:
# 걸어가라

# %%
# 돈이 3000원 이상 있거나 카드가 있다면 택시를 타고 가고, 그렇지 않으면 걸어 가세요

money = 1000 
card = False

if money >= 2000 or card == True:
    print("택시를 타세요")
else:
    print("걸어 가세요")
# Out:
# 걸어 가세요

# %%
#만약에 주머니에 money가 있으면 택시를 타고 가고, 그렇지 않으면 걸어가라

pocket = ["paper", "phone", "money"]

if "money" in pocket:
    print("택시를 타고 가세요")
else:
    print("걸어 가세요")
# Out:
# 택시를 타고 가세요

# %%
# 다양한 조건을 판단하는 elif
pocket = ["paper", "phone"]
card = False

if "money" in pocket:
    print("택시를 타고 가라")
else:
    if card == True:
        print("택시를 타고 가라")
    else:
        print("걸어가라")
# Out:
# 걸어가라

# %%
pocket = ["paper", "phone"]
card = False

if "money" in pocket:
    print("택시를 타고 가라")
elif card == True:
    print("택시를 타고 가라")
else: 
    print("걸어가라")
# Out:
# 걸어가라

# %%
# 조건부 표현식
score = 85
if score >= 60:
    result = "합격"
else:
    result = "불합격"
print(result)
# Out:
# 합격

# %%
# 학점이 90 이상이면 A, 
# 80이상 90미만이면 B,
# 70이상 80미만이면 C, 
# 60이상 70미만이면 D,
# 60미만이면 F

score = 85

if score >= 90:
    result = "A"
    score 80 >= 89:
    result = "B"
    score 70 >= 79:
    result = "C"
    score 60 >= 69:
    result = "D"
    score < 60:
    result = "F"
print(result)
# Out:
#   Cell In[35], line 11
#     score 80 >= 89:
#           ^
# SyntaxError: invalid syntax

# %%
score = input("학점을 입려하세요 : ")
# Out:
# '80'

# %%
int('80')
# Out:
# 80

# %%
score = int(input("학점을 입력하세요 : "))

if score >= 90:
    print(f"입력값은 {score} 당신의 학점은 : A")
elif score >= 80:  #and score < 90:  (#처리한 것은 굳이 안 써도 됨)
    print(f"입력값은 {score} 당신의 학점은 : B")
elif score >= 70:
    print(f"입력값은 {score} 당신의 학점은 : C")
elif score >= 60:
    print(f"입력값은 {score} 당신의 학점은 : D")
else:
    print(f"입력값은 {score} 당신의 학점은 : F")
# Out:
# 입력값은 99 당신의 학점은 : A
