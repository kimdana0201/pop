# %%
import mod1

mod1.add(3, 4)
mod1.sub(4, 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 4
#       1 import mod1
#       3 mod1.add(3, 4)
# ----> 4 mod1.sub(4, 3)
#
# AttributeError: module 'mod1' has no attribute 'sub'

# %%
from 클래스.mod1 import add, sub
print((add(7,10)))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from mod1 import add, sub
#       2 print((add(7,10)))
#
# ModuleNotFoundError: No module named 'mod1'

# %%
from 클래스.mod1 import *

print(add(10, 10))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from 클래스.mod1 import *
#       3 print(add(10, 10))
#
# ModuleNotFoundError: No module named '클래스'

# %%
from mod1 import add

add(3, 4)
# Out:
# -1
